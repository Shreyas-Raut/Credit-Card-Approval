# %% [markdown]
# # <font color=CYAN> **CAPSTONE PROJECT ON CREDIT CARD DATASET**

# %% [markdown]
# #### **INTRODUCTION**

# %% [markdown]
# **Credit cards** play a significant role for both customers and banks, offering various benefits and serving as a crucial financial tool.
# - **For customers**, providing convenience, flexibility, and a means to build credit. They offer a convenient payment method for various transactions, both online and offline. Responsible credit card use helps individuals establish and improve their credit history, enabling them to access favorable loan terms and financial products.
# - Credit cards also serve as a financial safety net during emergencies, providing quick access to funds. The rewards and perks associated with credit cards, such as cashback and travel benefits, enhance the overall customer experience. Moreover, credit cards offer security features and fraud protection, instilling confidence in users.
#
# - **For banks**, credit cards are a key revenue source. Interest on outstanding balances, along with fees like annual fees and late fees, contributes significantly to their income. Credit cards also foster customer loyalty, leading to increased engagement with other banking services.
# - The data generated by credit card transactions enables banks to understand consumer behavior, aiding in targeted marketing and personalized product offerings. Additionally, credit cards support risk management through sophisticated models, allowing banks to make informed lending decisions. Collaborations with businesses for co-branded cards further expand the customer base, making credit cards a strategic tool for both customers and banks.

# %% [markdown]
# **Importance in today's world:**
#
# In today's world, my proposal emphasizes the significance of credit cards for seamless transactions, credit-building, and financial security for customers. Predicting a good client is crucial for banks to minimize risks and optimize lending decisions.
#
# Utilizing sophisticated models, banks can assess creditworthiness, ensuring responsible lending practices. This not only safeguards the financial health of the bank but also fosters a sustainable and trustworthy banking relationship with clients. In an era of data-driven decision-making, accurately predicting a client's creditworthiness is paramount for maintaining a robust and stable financial ecosystem.

# %% [markdown]
# **If any, what is the gap in the knowledge or how your proposed method can be helpful if required in future for any bank in India?**
#
# If a bank in India were to consider implementing or refining credit card practices in the future, the proposed method outlined earlier could be beneficial.
#
# - The gaps in knowledge could potentially be addressed through continuous analysis and adaptation of credit scoring models. If specific challenges arise, such as changing consumer behaviors, economic fluctuations, or emerging fraud patterns, banks could **leverage data analytics and machine learning to enhance their risk management strategies.**
#
# - Additionally, **staying attuned to regulatory changes and customer preferences** is crucial. The proposed method's emphasis on **data analytics and targeted marketing** aligns with the evolving landscape of the banking sector, allowing banks to tailor credit card offerings based on customer needs while maintaining compliance with regulations.
#
# - To ensure ongoing relevance, **periodic reviews and updates to credit scoring models, risk management protocols, and customer engagement strategies** would be necessary. Continuous monitoring and adaptation to industry trends and technological advancements would contribute to the effectiveness of the proposed method in addressing potential future challenges in the credit card landscape for banks in India.

# %% [markdown]
# **PROBLEM STATEMENT FOR THE CAPSTONE**
#
# Utilize machine learning approaches to predict credit card approval based on customer information.
#
#
# A bank's credit card department is one of the top adopters of data science. A top focus for the bank has always been acquiring new credit card customers. Giving out credit cards without doing proper research or evaluating applicants' creditworthiness is quite risky. The credit card department has been using a data-driven system for credit assessment called Credit Scoring for many years, and the model is known as an application scorecard. A credit card application's cutoff value is determined using the application scorecard, which also aids in estimating the applicant's level of risk. This decision is made based on strategic priority at a given time.
#
#
# Customers must fill out a form, either physically or online, to apply for a credit card. The application data is used to evaluate the applicant's creditworthiness. The decision is made using the application data in addition to the Credit Bureau Score, such as the FICO Score in the US or the CIBIL Score in India, and other internal information on the applicants. Additionally, the banks are rapidly taking a lot of outside data into account to enhance the caliber of credit judgements.

# %% [markdown]
# **Initial Hypothesis:**
# - The information so filled in the form by the customers of the bank could be used to perform predictive analysis on the data and analyse credit worthiness of the customer and extract a Predictive model to predict whether a particular customer could be facilitated with Credit card.

# %% [markdown]
# **Approach for Data Analysis:**
# - **Data Understanding**
# - **Data Preprocessing**
#   - Data Cleaning
#   - Handling Null values, Outliers and dupliates along with appropriate datatypes and variables.
# - **Data Engineering**
#   - Encoding
#   - Categorization
# - **Feature Selection** - to take into consideration only the related variables in the model for prediction.
# - **Visualisation** for a wide picture of the dataset and comprehensive Data Analysis.

# %% [markdown]
# **MODELLING** - Running different models on cleaned data
# - Using **Classification models** on the data - Target variable in the Categorical form.
# - **Models Used**:
#   1. Logistic Regression Model
#   2. Random-Forest Model
#   3. K-Nearest Neighbor Classifier Model
#   4. Decision-Tree Classifier Model
# - Using **Hyperparameter Tuning** for countering the Overfitting problem.
# - Use **Cross-Validation score** for cross-checking accuracy with respect to different cross section of the data.
# - **Classification report** - To comprehensively understand about the precision, recall and their harmonic mean that is f1-score.
# - **Choosing appropriate model** - Comparing different models to choose one model with high accuracy from the models so used.

# %% [markdown]
# **DATA DESCRIPTION**
#
# Features name: (Credit_Card.csv)
#
# Ind_ID: Client ID
#
# Gender: Gender information
#
# Car_owner: Having car or not
#
# Propert_owner: Having property or not
#
# Children: Count of children
#
# Annual_income: Annual income
#
# Type_Income: Income type
#
# Education: Education level
#
# Marital_status: Marital_status
#
# Housing_type: Living style
#
# Birthday_count: Use backward count from current day (0), -1 means yesterday.
#
# Employed_days: Start date of employment. Use backward count from current day (0). Positive value means, individual is currently unemployed.
#
# Mobile_phone: Any mobile phone
#
# Work_phone: Any work phone
#
# Phone: Any phone number
#
# EMAIL_ID: Any email ID
#
# Type_Occupation: Occupation
#
# Family_Members: Family size
#
# **Another data set (Credit_card_label.csv) contains two key pieces of information**
#
# ID: The joining key between application data and credit status data, same is Ind_ID
#
# Label: 0 is application approved and 1 is application rejected.

# %% [markdown]
# #### **IMPORTING LIBRARIES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import seaborn as sns

# %% [markdown]
# #### **IMPORTING DATASET**

# %% [markdown]
# - Data provided in two csv files, thus merging the files to single dataframe

# %%
data = pd.read_csv("Credit_card.csv")
data1 = pd.read_csv("Credit_card_label.csv")

# Merging Dataframes
df = data.merge(data1)

# %% [markdown]
# #### **UNDERSTANDING DATA**

# %%
df.head()
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0       315000.0
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# ...

# %%
print("Shape of the dataset: ", data.shape)
# Out:
# Shape of the dataset:  (1548, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1548 entries, 0 to 1547
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ind_ID           1548 non-null   int64
#  1   GENDER           1541 non-null   object
#  2   Car_Owner        1548 non-null   object
#  3   Propert_Owner    1548 non-null   object
#  4   CHILDREN         1548 non-null   int64
#  5   Annual_income    1525 non-null   float64
#  6   Type_Income      1548 non-null   object
#  7   EDUCATION        1548 non-null   object
#  8   Marital_status   1548 non-null   object
#  9   Housing_type     1548 non-null   object
#  10  Birthday_count   1526 non-null   float64
#  11  Employed_days    1548 non-null   int64
#  12  Mobile_phone     1548 non-null   int64
#  13  Work_Phone       1548 non-null   int64
#  14  Phone            1548 non-null   int64
#  15  EMAIL_ID         1548 non-null   int64
#  16  Type_Occupation  1060 non-null   object
# ...

# %%
print('Data Description: \n\n',df.describe(include='all'))
# Out:
# Data Description:
#
#                Ind_ID GENDER Car_Owner Propert_Owner     CHILDREN  \
# count   1.548000e+03   1541      1548          1548  1548.000000
# unique           NaN      2         2             2          NaN
# top              NaN      F         N             Y          NaN
# freq             NaN    973       924          1010          NaN
# mean    5.078920e+06    NaN       NaN           NaN     0.412791
# std     4.171759e+04    NaN       NaN           NaN     0.776691
# min     5.008827e+06    NaN       NaN           NaN     0.000000
# 25%     5.045070e+06    NaN       NaN           NaN     0.000000
# 50%     5.078842e+06    NaN       NaN           NaN     0.000000
# 75%     5.115673e+06    NaN       NaN           NaN     1.000000
# max     5.150412e+06    NaN       NaN           NaN    14.000000
#
#         Annual_income Type_Income                      EDUCATION  \
# count    1.525000e+03        1548                           1548
# ...

# %%
# Numerical Variables
print("Numerical variables \n\n",df.describe(include=[np.number]))
print('\n\n')

# Text Variables
print("Text Variables: \n\n",df.describe(exclude=[np.number]))
# Out:
# Numerical variables
#
#               Ind_ID     CHILDREN  Annual_income  Birthday_count  \
# count  1.548000e+03  1548.000000   1.525000e+03     1526.000000
# mean   5.078920e+06     0.412791   1.913993e+05   -16040.342071
# std    4.171759e+04     0.776691   1.132530e+05     4229.503202
# min    5.008827e+06     0.000000   3.375000e+04   -24946.000000
# 25%    5.045070e+06     0.000000   1.215000e+05   -19553.000000
# 50%    5.078842e+06     0.000000   1.665000e+05   -15661.500000
# 75%    5.115673e+06     1.000000   2.250000e+05   -12417.000000
# max    5.150412e+06    14.000000   1.575000e+06    -7705.000000
#
#        Employed_days  Mobile_phone   Work_Phone        Phone     EMAIL_ID  \
# count    1548.000000        1548.0  1548.000000  1548.000000  1548.000000
# mean    59364.689922           1.0     0.208010     0.309432     0.092377
# std    137808.062701           0.0     0.406015     0.462409     0.289651
# ...

# %%
# Columns
df.columns
# Out:
# Index(['Ind_ID', 'GENDER', 'Car_Owner', 'Propert_Owner', 'CHILDREN',
#        'Annual_income', 'Type_Income', 'EDUCATION', 'Marital_status',
#        'Housing_type', 'Birthday_count', 'Employed_days', 'Mobile_phone',
#        'Work_Phone', 'Phone', 'EMAIL_ID', 'Type_Occupation', 'Family_Members',
#        'label'],
#       dtype='object')

# %%
# Unique Values
for i in df.columns:
  print(i)
  print(df[i].unique())
  print("\n")
# Out:
# Ind_ID
# [5008827 5009744 5009746 ... 5115992 5118219 5053790]
#
#
# GENDER
# ['M' 'F' nan]
#
#
# Car_Owner
# ['Y' 'N']
#
#
# Propert_Owner
# ['Y' 'N']
#
#
# CHILDREN
# [ 0  1  2  4  3 14]
#
#
# Annual_income
# [ 180000.   315000.        nan  450000.    90000.   472500.   270000.
#   126000.   202500.   157500.   112500.   540000.   292500.   135000.
#    76500.   215100.   225000.    67500.   171000.   103500.    99000.
#   391500.    65250.    72900.   360000.   256500.   675000.   247500.
#    85500.   121500.   130500.   211500.    81000.    72000.   148500.
#   162000.   195750.   585000.   216000.   306000.   108000.    63000.
#    45000.   337500.   131400.   117000.   445500.   234000.  1575000.
#   144000.    67050.    73350.   193500.   900000.    94500.   198000.
#    54000.   166500.   167400.   153000.   423000.   243000.   283500.
#   252000.   495000.   612000.    36000.   139500.   133650.   427500.
# ...

# %% [markdown]
# #### **DATA PRE-PROCESSING**

# %%
df.head()
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0       315000.0
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# ...

# %%
# Renaming few variables
df = df.rename(columns = {'GENDER':'Gender','CHILDREN':'Children', 'Propert_Owner': 'Property_Owner','EDUCATION':'Education'})

# %%
# Converting Birthday_count to Age
df['Age'] = round(abs(df['Birthday_count']/365),0) # Absolute values for negative numbers
# Dropping Birthday_count column
df = df.drop(columns =['Birthday_count'])

# %%
# Converting Employed days to Employed_years
df['Employed_days'] = round(df['Employed_days']/365,0)
df['Employed_years'] = df['Employed_days'].abs().astype('int')
df = df.drop(columns =['Employed_days'])

# %%
# Dropping Irrelevant Columns i.e the columns which does not provide input to evaluate creditworthiness of the customer
df = df.drop(columns=['Ind_ID','Mobile_phone','Work_Phone','Phone','EMAIL_ID'])

# %%
df.head()
# Out:
#   Gender Car_Owner Property_Owner  Children  Annual_income  \
# 0      M         Y              Y         0       180000.0
# 1      F         Y              N         0       315000.0
# 2      F         Y              N         0       315000.0
# 3      F         Y              N         0            NaN
# 4      F         Y              N         0       315000.0
#
#             Type_Income         Education Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#   Type_Occupation  Family_Members  label   Age  Employed_years
# 0             NaN               2      1  51.0            1001
# ...

# %% [markdown]
# #### **Handling Null Values**

# %%
# Null Values Count
df.isnull().sum()
# Out:
# Gender               7
# Car_Owner            0
# Property_Owner       0
# Children             0
# Annual_income       23
# Type_Income          0
# Education            0
# Marital_status       0
# Housing_type         0
# Type_Occupation    488
# Family_Members       0
# label                0
# Age                 22
# Employed_years       0
# dtype: int64

# %%
# Null Values Percentage
df.isnull().sum()/len(df)*100
# Out:
# Gender              0.452196
# Car_Owner           0.000000
# Property_Owner      0.000000
# Children            0.000000
# Annual_income       1.485788
# Type_Income         0.000000
# Education           0.000000
# Marital_status      0.000000
# Housing_type        0.000000
# Type_Occupation    31.524548
# Family_Members      0.000000
# label               0.000000
# Age                 1.421189
# Employed_years      0.000000
# dtype: float64

# %%
# Matrix for the missing values
import missingno as msno
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# #### **Insights**
# - Analysing considering the unique function, isnull function and missing number matrix we canconclude that there are only 4 columns with Null Values.
#   - Gender
#   - Annual_income
#   - Birthday_count
#   - Type_Occupation
# - Herein, missing values in Gender, Annual_income and Birthday_count column is less than 1.5 % of the length of the data and thus can be handled statistically without much impact on the unbiased analysis.

# %% [markdown]
# - There are 488 missing values in Type_Occupation column which is approximately 32% of the length of the data which is comparatively higher to ensure the unbiased and predictive analysis.
# - Thus it is better to drop the column from the data.

# %%
# 1 Handling Type_Occupation column
df = df.drop(columns = ['Type_Occupation'])

# %%
# 2 Handling Gender Column
df['Gender']=df['Gender'].fillna(df["Gender"].mode()[0])

# %%
# 3 Handling Annual_income column
df["Annual_income"] = df['Annual_income'].fillna(df['Annual_income'].mean())

# %%
import plotly.express as px
px.box(df['Age'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - No outlier in Age column thus we can use mean to fill the missing values in Age column. (Since the outliers are sensitive to mean)

# %%
# 4 Handling Birthday_count column
df["Age"] = df['Age'].fillna(df['Age'].mean())
df['Age'] = df['Age'].astype('int')

# %%
# Matrix for the missing values
import missingno as msno
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# - Now we can see from the matrix that the null values from the dataset has been worked on and none of the null values exists now.

# %% [markdown]
# #### **Handling Outliers and Abnormal Values**

# %%
# Employed_years
df['Employed_years'].unique()
# Out:
# array([1001,    2,    3,    1,    7,    5,   12,    9,   13,   10,    4,
#          20,    6,   11,    0,   23,    8,   14,   19,   22,   21,   17,
#          26,   24,   15,   16,   34,   37,   27,   41,   35,   18,   31,
#          32,   25,   29,   38,   33,   28,   36])

# %%
px.box(df['Employed_years'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# In Employed_years column,
# - There is only one abnormal value 1001 as we can see in the unique values of the Employed_years column.
# - Employed_years - 1001 which is not possible thus dropping those rows with employed_years = 1001.

# %%
# dropping rows with Employed_years == 1001 - Abnormal values/Outlier
df = df.drop(index = df[df['Employed_years']==1001].index)

# %% [markdown]
# In Children column,
# - Common sensically 14 children is an abnormal sort value or if it exists its rarest of the rare case and thus we can drop the particular row.

# %%
#  Handling Children variable
df['Children'].unique()
df[df['Children']==14]
# Out:
#     Gender Car_Owner Property_Owner  Children  Annual_income Type_Income  \
# 565      M         Y              Y        14       225000.0     Working
#
#                          Education Marital_status       Housing_type  \
# 565  Secondary / secondary special      Separated  House / apartment
#
#      Family_Members  label  Age  Employed_years
# 565              15      0   49               5

# %%
# dropping record with index 565
df = df.drop(index=[565])

# %% [markdown]
# #### **VISUALIZING**

# %%
df.head()
# Out:
#   Gender Car_Owner Property_Owner  Children  Annual_income  \
# 1      F         Y              N         0   315000.00000
# 2      F         Y              N         0   315000.00000
# 3      F         Y              N         0   191399.32623
# 4      F         Y              N         0   315000.00000
# 5      F         Y              N         0   315000.00000
#
#             Type_Income         Education Marital_status       Housing_type  \
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
# 5             Pensioner  Higher education        Married  House / apartment
#
#    Family_Members     label  Age  Employed_years
# 1               2  Rejected   37               2
# 2               2  Rejected   43               2
# ...

# %%
# Categorization
df['label'] = df['label'].map({0:'Approved', 1:'Rejected'})

# %%
# 1. Credit Card Application Status
count = df['label'].value_counts()
plt.pie(count, labels = ["Credit_card Approved","Credit_card Rejected"], autopct = "%1.2f%%")
plt.title("Credit Card Application Status")
plt.show()

# %% [markdown]
# **Insights**:
# - Credit card approval rate is substantially high around 89%.

# %%
# 2. Columns Vs Target Variable ('Label')
for i in df.columns:
  if i not in ['label','Annual_income']:
    a = df.groupby([i,'label'],as_index=False).size().rename(columns={'size':'Count'})
    a['percent']=round(a['Count']*100/a.groupby(i)['Count'].transform('sum'),1)
    a['percent']=a['percent'].apply(lambda x: '{}%'.format(x))
    fig=px.bar(a,x=i,y='Count',text='percent',color='label',barmode='group',color_discrete_sequence=['brown','tomato'],title=i + ' Vs Label')
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Insights**:
# - **Gender**
#   - Female count for Credi card approval is more than that of male.
#   - Rejection rate in Males is comparatively higher than female.
# - **Children**
#   - Couples with 0-2 number of children has comparatively higher chances of approval of credit card
# - **Type_Income**
#   - Working and Commercial associates has a fairly good chance of availing the Credit card.
#   - Also among the state-servant, credit card approval rate is good.
# - **Education**
#   - Secondar Education, Higher Education and persons with Academic degree has better chances of getting their Credit card request approved.
# - **Marital status**
#   - Married persons seems to have a good chance of getting Credit cards.
# - **Housing_type**
#   - Persons with House/Apartment have a good approval rate for credit card.
# - **Age**
#   - Persons with Age between 25-55 have a fairly better chance of availing Credit cards.
# - **Employed_years**
#   - Approval rate for credit cards with employment years less than 15 seems to have gotten more credit cards approved.

# %% [markdown]
# #### **ENCODING :** **Converting Categorical Variables to Numeric Variables**

# %%
# Analysing through Unique Values in the column
for i in df.columns:
  print(i)
  print(df[i].unique())
  print("\n")
# Out:
# Gender
# ['F' 'M']
#
#
# Car_Owner
# ['Y' 'N']
#
#
# Property_Owner
# ['N' 'Y']
#
#
# Children
# [0 1 2 4 3]
#
#
# Annual_income
# [ 315000.          191399.32622951  450000.           90000.
#   472500.          270000.          126000.          202500.
#   157500.          112500.          180000.          540000.
#   292500.          135000.          215100.           67500.
#   171000.          103500.          225000.          391500.
#   360000.          256500.          675000.          247500.
#    85500.          121500.          130500.          211500.
#    72000.          195750.          585000.          216000.
#   108000.           81000.           63000.          337500.
#   117000.          445500.          234000.         1575000.
#   144000.           73350.          193500.          900000.
#    76500.           94500.          198000.          306000.
#   166500.           99000.          153000.          423000.
# ...

# %%
# 1. Gender
# Mapping
df['Gender'] = df['Gender'].map({'F':0, 'M':1})

# %%
# 2. Car_Owner
# Mapping
df['Car_Owner'] = df['Car_Owner'].map({'N':0, 'Y':1})

# %%
# 3. Property_Owner
# Mapping
df['Property_Owner'] = df['Property_Owner'].map({'N':0, 'Y':1})

# %%
# 4. Type_Income
# Label Encoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Type_Income'] = le.fit_transform(df[['Type_Income']])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
# 5. Education
# Mapping - Ordinal Encoding
df['Education'] = df['Education'].map({'Lower secondary':0,'Secondary / secondary special':1,'Incomplete higher':2,'Higher education':3,'Academic degree':4})

# %%
# 6. Marital_status
# Label Encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Marital_status'] = le.fit_transform(df[['Marital_status']])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
# 7. Housing_type
# Label Encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Housing_type'] = le.fit_transform(df[['Housing_type']])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %% [markdown]
# **TESTING MULTICOLLINEARITY**
#   - The default VIF cutoff value is 5; only variables with a VIF less than 5 will be included in the model.

# %%
df.head()

# %%
# Examine multicollinearity using VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor


# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = df.columns

# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(df.values, i) for i in range(len(df.columns))]

print(vif_data)
# Out:
#            feature        VIF
# 0           Gender   1.992933
# 1        Car_Owner   2.104467
# 2   Property_Owner   2.792526
# 3         Children   8.052119
# 4    Annual_income   4.550967
# 5      Type_Income   3.569172
# 6        Education   4.425819
# 7   Marital_status   4.575913
# 8     Housing_type   2.739560
# 9   Family_Members  37.359051
# 10           label   1.159636
# 11             Age  21.036453
# 12  Employed_years   2.607370

# %% [markdown]
# - Since for the variables 'Children', 'Family_Members' and 'Age', the VIF value is more than 5, thus can be eliminated to avoid the issue of Multicollinearity

# %%
df = df.drop(columns={'Children','Family_Members','Age'})

# %% [markdown]
# #### **FEATURE SELECTION**

# %% [markdown]
# - **P_value > Alpha** - accept H0 i.e No relation - unimportant variable for prediction
# - **P_value < Alpha** - accept H1 i.e Relation - important variable for prediction
# - **Alpha** (SIgnificance Level) = 0.05

# %%
df.columns
# Out:
# Index(['Gender', 'Car_Owner', 'Property_Owner', 'Annual_income', 'Type_Income',
#        'Education', 'Marital_status', 'Housing_type', 'label',
#        'Employed_years'],
#       dtype='object')

# %%
from scipy.stats import chi2_contingency
dset = ['Gender','Car_Owner','Property_Owner','Type_Income','Education', 'Marital_status','Housing_type',
        'Annual_income','Employed_years']

for i in dset:
  table = pd.crosstab(df[i],df['label'])
  chi2,p_value,dof,expected = chi2_contingency(table)
  print(i)
  print('p_value:',p_value)
  # interpret p-value
  alpha = 0.05 # Significance Level
  if p_value <= alpha:
    print('p_value < alpha')
    print('Dependent (reject H0)')
    print(i,'is an important variable for prediction of Approval or Rejection of the Credit card')
  else:
    print('p_value > alpha')
    print('Independent (H0 holds true)')
    print(i,'is not an important variable for prediction of Approval or Rejection of the Credit card')
  print('\n')
# Out:
# Gender
# p_value: 0.03166600189384587
# p_value < alpha
# Dependent (reject H0)
# Gender is an important variable for prediction of Approval or Rejection of the Credit card
#
#
# Car_Owner
# p_value: 0.6612887570234456
# p_value > alpha
# Independent (H0 holds true)
# Car_Owner is not an important variable for prediction of Approval or Rejection of the Credit card
#
#
# Property_Owner
# p_value: 0.8835971407865929
# p_value > alpha
# Independent (H0 holds true)
# Property_Owner is not an important variable for prediction of Approval or Rejection of the Credit card
#
#
# Type_Income
# p_value: 3.2608197271212878e-12
# p_value < alpha
# Dependent (reject H0)
# Type_Income is an important variable for prediction of Approval or Rejection of the Credit card
#
#
# Education
# p_value: 0.020620543612047886
# p_value < alpha
# Dependent (reject H0)
# Education is an important variable for prediction of Approval or Rejection of the Credit card
#
#
# Marital_status
# ...

# %% [markdown]
# - Thus we can skip unrelated variables i.e **Car_Owner and Property_Owner**.

# %%
df = df.drop(columns=['Car_Owner','Property_Owner'])

# %% [markdown]
# #### **MODELLING**

# %% [markdown]
# - Training the models for predictive analysis.

# %% [markdown]
# **MODEL I - LOGISTIC REGRESSION MODEL**

# %%
X = df[['Gender','Annual_income',
       'Type_Income', 'Education', 'Marital_status', 'Housing_type','Employed_years']]
y = df['label']

# Splitting the data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=True)

# Importing Logistic Regression model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train)

# Make predictions on the testing data
y_pred = model.predict(X_test)

# Accuracy Score %
from sklearn.metrics import accuracy_score
score_lr = round(accuracy_score(y_test,y_pred)*100,2)
print('Test Accuracy: ', score_lr,'%')

# Train accuracy
y_pred_train = model.predict(X_train)
train_accuracy_lr = round(accuracy_score(y_train,y_pred_train)*100,2)
print('Train Accuracy:',train_accuracy_lr,'%')

# Cross Validation
from sklearn.model_selection import cross_val_score
cv_score_lr = round(cross_val_score(model,X_train,y_train,cv=5).mean()*100,2)
print('CV_score: ',cv_score_lr,'%')
# Out:
# Test Accuracy:  87.98 %
# Train Accuracy: 89.4 %
# CV_score:  89.4 %

# %%
# Classification Report
from sklearn.metrics import classification_report
CR = classification_report(y_test,y_pred)
print('Classification Report: ',CR)
# Out:
# Classification Report:                precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94       227
#            1       0.00      0.00      0.00        31
#
#     accuracy                           0.88       258
#    macro avg       0.44      0.50      0.47       258
# weighted avg       0.77      0.88      0.82       258
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# ...

# %%
# Confusion matrix and Cnfusion display
from sklearn.metrics import confusion_matrix
CM = confusion_matrix(y_test,y_pred)
print('Confusion Matrix: ', CM)

import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay
cm_display = ConfusionMatrixDisplay(confusion_matrix = CM, display_labels = [False, True])

cm_display.plot()
plt.show()
# Out:
# Confusion Matrix:  [[227   0]
#  [ 31   0]]

# %% [markdown]
# **MODEL II- RANDOM-FOREST MODEL**

# %%
X = df[['Gender','Annual_income',
       'Type_Income', 'Education', 'Marital_status', 'Housing_type', 'Employed_years']]
y = df['label']

# Split the data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state=True)

# Modelling
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=54)
model.fit(X_train,y_train)

# predict on test data
y_pred_test = model.predict(X_test)

# Evaluation
from sklearn.metrics import accuracy_score
score_rf = round(accuracy_score(y_test,y_pred_test)*100,2)
print('Test Accuracy: ', score_rf,'%')

# Train accuracy
y_pred_train = model.predict(X_train)
train_accuracy_rf = round(accuracy_score(y_train,y_pred_train)*100,2)
print('Train Accuracy:',train_accuracy_rf,'%')

# Cross Validation
from sklearn.model_selection import cross_val_score
cv_score_rf = round(cross_val_score(model,X_train,y_train,cv=5).mean()*100,2)
print('CV_score: ',cv_score_rf,'%')
# Out:
# Test Accuracy:  89.53 %
# Train Accuracy: 97.86 %
# CV_score:  90.17 %

# %%
# Hyperparameter Tuning
from sklearn.model_selection import GridSearchCV
# Grid - the list of values for which you have to check
# Search - identify the best one
# CV - which gives highest/max CV score

estimator = RandomForestClassifier()
param_grid = {'n_estimators':list(range(1,100))} # if the last value is the best value increase the value
grid = GridSearchCV(estimator,param_grid,cv=5)
grid.fit(X_train,y_train)
grid.best_params_

# then put n_estimators = ans in RandomForestClassifier model but if the last value is the best value increase the range.
# Out:
# {'n_estimators': 53}

# %% [markdown]
# **MODEL III - K-NEAREST NEIGHBOUR CLASSIFIER**

# %%
X = df[['Gender','Annual_income',
       'Type_Income', 'Education', 'Marital_status', 'Housing_type',
       'Employed_years']]
y = df['label']

# Split
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=True)

# model
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=7)
model.fit(X_train,y_train)


# Prediction on test data
y_pred_test = model.predict(X_test)

# Evaluation
from sklearn.metrics import accuracy_score
score_knn = round(accuracy_score(y_test,y_pred_test)*100,2)
print('Test Accuracy: ',score_knn,'%')

# Train accuracy
y_pred_train = model.predict(X_train)
train_accuracy_knn = round(accuracy_score(y_train,y_pred_train)*100,2)
print('Train Accuracy:',train_accuracy_knn,'%')

# Cross Validation
from sklearn.model_selection import cross_val_score
cv_score_knn = round(cross_val_score(model,X_train,y_train,cv=5).mean()*100,2)
print('CV_score: ',cv_score_knn,'%')
# Out:
# Test Accuracy:  88.37 %
# Train Accuracy: 89.79 %
# CV_score:  88.62 %

# %%
# Hyperparameter Tuning
from sklearn.model_selection import GridSearchCV
# Grid - the list of values for which you have to check
# Search - identify the best one
# CV - which gives highest/max CV score

estimator = KNeighborsClassifier()
param_grid = {'n_neighbors':list(range(1,11))} # if the last value is the best value increase the value
grid = GridSearchCV(estimator,param_grid,cv=5)
grid.fit(X_train,y_train)
grid.best_params_

# then put n_neighbors = ans in KNNClassifier model but if the last value is the best value increase the range.
# Out:
# {'n_neighbors': 10}

# %% [markdown]
# **MODEL IV - DECISION-TREE CLASSIFIER**

# %%
X = df[['Gender','Annual_income',
       'Type_Income', 'Education', 'Marital_status', 'Housing_type',
       'Employed_years']]
y = df['label']

# Split the data into train and test data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2,random_state=True)

# Modelling
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(max_depth=3)
model.fit(X_train,y_train)

# normal prediction
y_pred = model.predict(X_test)

# prediction of test_data
y_pred_test = model.predict(X_test) #same

# Evaluation of test_data
from sklearn.metrics import accuracy_score
score = round(accuracy_score(y_test,y_pred_test)*100,2)
print('Test Accuracy',score,'%')

# prediction of train_data
y_pred_train = model.predict(X_train)

# Evaluation of train_data
from sklearn.metrics import accuracy_score
score_dtc = round(accuracy_score(y_train,y_pred_train)*100,2)
print('Train Accuracy: ',score_dtc,'%')

# using max_depth=7 to overcome Overfitting problem and bring the difference between test accuracy and train accuracy within 5% range.

# Cross Validation
from sklearn.model_selection import cross_val_score
cv_score_dtc = round(cross_val_score(model,X_train,y_train,cv=5).mean()*100,2)
print('CV_score: ',cv_score_dtc,'%')
# Out:
# Test Accuracy 87.6 %
# Train Accuracy:  90.08 %
# CV_score:  89.4 %

# %%
# Hyperparameter Tuning
from sklearn.model_selection import GridSearchCV
# Grid - the list of values for which you have to check
# Search - identify the best one
# CV - which gives highest/max CV score

estimator = DecisionTreeClassifier()
param_grid = {'max_depth':list(range(1,10))} # if the last value is the best value increase the value
grid = GridSearchCV(estimator,param_grid,cv=5)
grid.fit(X_train,y_train)
grid.best_params_

# then put n_estimators = ans in XGBClassifier model but if the last value is the best value increase the range.
# Out:
# {'max_depth': 1}

# %% [markdown]
# #### **CHOOSING APPROPRIATE MODEL**

# %%
Classifiers = ['Logistic Regression','Random Forest Classifier','K-Nearest Neighbour ','Decision-Tree Classifier']
Accuracy = [score_lr,score_rf,score_knn,score_dtc]
Cross_Validation = [cv_score_lr,cv_score_rf,cv_score_knn,cv_score_dtc]

# %%
Classifier_data = pd.DataFrame({'Classifiers':Classifiers,'Test Accuracy %':Accuracy,'Cross_Validation %':Cross_Validation})
Classifier_data
# Out:
#                 Classifiers  Test Accuracy %  Cross_Validation %
# 0       Logistic Regression            87.98               89.40
# 1  Random Forest Classifier            89.53               90.17
# 2      K-Nearest Neighbour             88.37               88.62
# 3  Decision-Tree Classifier            90.08               89.40

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Bar( x = Classifiers, y=list(Accuracy), name= 'Accuracy', marker_color='darkcyan', text=list(Accuracy)))
fig.add_trace(go.Bar( x = Classifiers, y=list(Cross_Validation), name= 'Cross_Validation', marker_color='lightsalmon', text=list(Cross_Validation) ))
fig.update_layout(barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### **CONCLUSION**
#   - Hovering through the different Classifiers, their test accuracy in the plot and also refering to the Classifier_data table, we can conclude that **Random-Forest or Decision-Tree with around 90% test accuracy and Cross Validation score upto 90% would be the best models** to use to predict whether a particular customer's application for Credit card will be Approved or Rejected.

# %% [markdown]
# # <FONT COLOR=cyan>**SQL QUESTIONS**

# %%
df.head()
# Out:
#    Gender  Children  Annual_income  Type_Income  Education  Marital_status  \
# 1       0         0   315000.00000            0          3               1
# 2       0         0   315000.00000            0          3               1
# 3       0         0   191399.32623            0          3               1
# 4       0         0   315000.00000            0          3               1
# 5       0         0   315000.00000            1          3               1
#
#    Housing_type     label  Age  Employed_years
# 1             1  Rejected   37               2
# 2             1  Rejected   43               2
# 3             1  Rejected   37               2
# 4             1  Rejected   37               2
# 5             1  Rejected   37               2

# %% [markdown]
# **Data Cleaning**

# %%
import pandas as pd
data = pd.read_csv("Credit_card.csv")
data1 = pd.read_csv("Credit_card_label.csv")

# Merging Dataframes
df = data.merge(data1)

# Renaming few variables
df = df.rename(columns = {'GENDER':'Gender','CHILDREN':'Children', 'Propert_Owner': 'Property_Owner','EDUCATION':'Education'})

# Converting Birthday_count to Age
df['Age'] = round(abs(df['Birthday_count']/365),0) # Absolute values for negative numbers
# Dropping Birthday_count column
df = df.drop(columns =['Birthday_count'])

# Converting Employed days to Employed_years
df['Employed_days'] = round(df['Employed_days']/365,0)
df['Employed_years'] = df['Employed_days'].abs().astype('int')
df = df.drop(columns =['Employed_days'])

# Dropping Irrelevant Columns i.e the columns which does not provide input to evaluate creditworthiness of the customer
df = df.drop(columns=['Ind_ID','Mobile_phone','Work_Phone','Phone','EMAIL_ID'])

# 1 Handling Type_Occupation column
df = df.drop(columns = ['Type_Occupation'])

# 2 Handling Gender Column
df['Gender']=df['Gender'].fillna(df["Gender"].mode()[0])

# 3 Handling Annual_income column
df["Annual_income"] = df['Annual_income'].fillna(df['Annual_income'].mean())

# 4 Handling Birthday_count column
df["Age"] = df['Age'].fillna(df['Age'].mean())
df['Age'] = df['Age'].astype('int')

# dropping rows with Employed_years == 1001 - Abnormal values/Outlier
df = df.drop(index = df[df['Employed_years']==1001].index)

# dropping record with index 565
df = df.drop(index=[565])

df['label'] = df['label'].map({0:'Approved', 1:'Rejected'})

# %%
import duckdb
conn = duckdb.connect()
conn.register('data',data)

# %% [markdown]
# **Q1. Group the customers based on their income type and find the average of their annual income.**

# %%
conn.execute("Select Type_Income, AVG(Annual_income) as Average_Annual_Income from df GROUP BY Type_Income;").fetchdf()
# Out:
#             Type_Income  Average_Annual_Income
# 0             Pensioner          288000.000000
# 1               Working          181136.467489
# 2         State servant          211422.413793
# 3  Commercial associate          233653.135917

# %%
df.head()
# Out:
#   Gender Car_Owner Property_Owner  Children  Annual_income  \
# 1      F         Y              N         0   315000.00000
# 2      F         Y              N         0   315000.00000
# 3      F         Y              N         0   191399.32623
# 4      F         Y              N         0   315000.00000
# 5      F         Y              N         0   315000.00000
#
#             Type_Income         Education Marital_status       Housing_type  \
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
# 5             Pensioner  Higher education        Married  House / apartment
#
#    Family_Members     label  Age  Employed_years
# 1               2  Rejected   37               2
# 2               2  Rejected   43               2
# ...

# %% [markdown]
# **Q2. Find the female owners of cars and property.**

# %%
conn.execute("SELECT * FROM df WHERE GENDER=='F' and Car_Owner=='Y' and Property_Owner=='Y' ").fetchdf()
# Out:
#     Gender Car_Owner Property_Owner  Children  Annual_income  \
# 0        F         Y              Y         0    90000.00000
# 1        F         Y              Y         0   191399.32623
# 2        F         Y              Y         0    90000.00000
# 3        F         Y              Y         0   540000.00000
# 4        F         Y              Y         0   180000.00000
# ..     ...       ...            ...       ...            ...
# 148      F         Y              Y         0   180000.00000
# 149      F         Y              Y         1   126000.00000
# 150      F         Y              Y         3   180000.00000
# 151      F         Y              Y         1   144000.00000
# 152      F         Y              Y         0   225000.00000
#
#               Type_Income                      Education Marital_status  \
# 0                 Working  Secondary / secondary special        Married
# 1                 Working  Secondary / secondary special        Married
# ...

# %% [markdown]
# **Q3. Find the male customers who are staying with their families.**

# %%
df['Housing_type'].unique()
# Out:
# array(['House / apartment', 'With parents', 'Rented apartment',
#        'Municipal apartment', 'Co-op apartment', 'Office apartment'],
#       dtype=object)

# %%
conn.execute("SELECT * FROM df WHERE Housing_type == 'With parents'").fetchdf()
# Out:
#    Gender Car_Owner Property_Owner  Children  Annual_income  \
# 0       M         N              N         1       472500.0
# 1       M         Y              N         0       202500.0
# 2       M         Y              N         0       202500.0
# 3       M         Y              N         0       202500.0
# 4       F         N              Y         2       135000.0
# ..    ...       ...            ...       ...            ...
# 75      M         N              N         0       270000.0
# 76      F         Y              Y         0       247500.0
# 77      M         Y              Y         0       135000.0
# 78      F         N              N         0        67500.0
# 79      M         Y              Y         0       225000.0
#
#              Type_Income                      Education        Marital_status  \
# 0              Pensioner               Higher education               Married
# 1                Working  Secondary / secondary special               Married
# ...

# %% [markdown]
# **Q4. Please list the top five people having the highest income.**

# %%
conn.execute("SELECT * FROM df ORDER BY Annual_income DESC LIMIT 5").fetchdf()
# Out:
#   Gender Car_Owner Property_Owner  Children  Annual_income  \
# 0      F         Y              Y         1      1575000.0
# 1      F         Y              Y         1      1575000.0
# 2      M         N              Y         1       900000.0
# 3      M         Y              Y         2       900000.0
# 4      M         Y              Y         2       900000.0
#
#             Type_Income                      Education        Marital_status  \
# 0  Commercial associate               Higher education  Single / not married
# 1  Commercial associate               Higher education  Single / not married
# 2               Working  Secondary / secondary special               Married
# 3  Commercial associate               Higher education               Married
# 4  Commercial associate               Higher education               Married
#
#         Housing_type  Family_Members     label  Age  Employed_years
# 0  House / apartment               2  Approved   28               7
# ...

# %% [markdown]
# **Q5. How many married people are having bad credit?**

# %%
conn.execute("SELECT * FROM df WHERE Marital_status == 'Married' and label=='Rejected'").fetchdf()
# Out:
#    Gender Car_Owner Property_Owner  Children  Annual_income  \
# 0       F         Y              N         0   315000.00000
# 1       F         Y              N         0   315000.00000
# 2       F         Y              N         0   191399.32623
# 3       F         Y              N         0   315000.00000
# 4       F         Y              N         0   315000.00000
# ..    ...       ...            ...       ...            ...
# 86      M         Y              N         1   450000.00000
# 87      F         Y              N         1   450000.00000
# 88      M         Y              Y         0   315000.00000
# 89      F         N              Y         0   157500.00000
# 90      F         N              Y         0   157500.00000
#
#              Type_Income                      Education Marital_status  \
# 0   Commercial associate               Higher education        Married
# 1   Commercial associate               Higher education        Married
# ...

# %% [markdown]
# **Q6. What is the highest education level and what is the total count?**

# %%
df['Education'].unique()
# Out:
# array(['Higher education', 'Secondary / secondary special',
#        'Lower secondary', 'Incomplete higher', 'Academic degree'],
#       dtype=object)

# %% [markdown]
# - Academic Degree is the highest education level.

# %%
conn.execute("SELECT count() as Count FROM df WHERE Education == 'Academic degree'").fetchdf()
# Out:
#    Count
# 0      2

# %% [markdown]
# - Count of Education of customer as Academic degree is 2.

# %% [markdown]
# **Q7. Between married males and females, who is having more bad credit?**

# %%
X = conn.execute("SELECT label, Gender, count()as Count FROM df WHERE Marital_status=='Married' GROUP BY label, Gender").fetchdf()

# %%
X
# Out:
#       label Gender  Count
# 0  Rejected      F     44
# 1  Rejected      M     47
# 2  Approved      F    470
# 3  Approved      M    335

# %%
px.bar(X,x='Gender',y='Count',color='label',barmode='group',text_auto=True,height=400,width=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - Between Married Males and Females, we can conclude that **Married Males** have bad credit as compared to Married females.
